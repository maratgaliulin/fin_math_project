# %%
# Импорт классов dfContainer, dfContainerIntraDay

from classes.df_container import dfContainer
from classes.df_container_intraday import dfContainerIntraDay

# %%
df_cont = dfContainer("data/EUR_USD Historical Data.csv")  # Создание объекта dfContainer

# %%
df_cont.draw_graph(start_date='2021-10-01', end_date='2022-01-01')  # Отрисовка графика с помощью метода draw_graph()

# %%
df_cont_15_min = dfContainerIntraDay('data/EURUSD_01-12-2022_09-12-2023.csv')  # Создание объекта dfContainerIntraDay

# %%
df_cont_15_min.show_head(250)
# Out:
#                        Date    Time     Open     High      Low    Close  \
# 2022-12-01 00:15:00  221201  001500  1.04072  1.04090  1.03965  1.04048
# 2022-12-01 00:30:00  221201  003000  1.04047  1.04066  1.04009  1.04055
# 2022-12-01 00:45:00  221201  004500  1.04055  1.04082  1.03984  1.04054
# 2022-12-01 01:00:00  221201  010000  1.04054  1.04090  1.04018  1.04041
# 2022-12-01 01:15:00  221201  011500  1.04041  1.04070  1.03981  1.04015
# ...                     ...     ...      ...      ...      ...      ...
# 2022-12-05 10:00:00  221205  100000  1.05713  1.05753  1.05670  1.05687
# 2022-12-05 10:15:00  221205  101500  1.05690  1.05714  1.05524  1.05595
# 2022-12-05 10:30:00  221205  103000  1.05598  1.05651  1.05560  1.05575
# 2022-12-05 10:45:00  221205  104500  1.05575  1.05651  1.05500  1.05519
# 2022-12-05 11:00:00  221205  110000  1.05520  1.05533  1.05290  1.05382
#
#                       Volume
# 2022-12-01 00:15:00  37376.0
# 2022-12-01 00:30:00  13960.0
# ...

# %%
df_cont_15_min.draw_graph(start_date='2023-06-01', vol=True, type_graph=1, fig_sz=(19, 8)) # Отрисовка графика с помощью метода draw_graph()
