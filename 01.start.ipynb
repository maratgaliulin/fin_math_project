# %%
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt

# %%
eur_usd_df = pd.read_csv("EUR_USD Historical Data.csv", index_col='Date').drop('Vol.', axis=1)

# %%
eur_usd_df['Close'] = eur_usd_df['Price']

# %%
eur_usd_df.index = pd.to_datetime(eur_usd_df.index)

# %%
eur_usd_df.index
# Out:
# DatetimeIndex(['2023-12-01', '2023-11-30', '2023-11-29', '2023-11-28',
#                '2023-11-27', '2023-11-24', '2023-11-23', '2023-11-22',
#                '2023-11-21', '2023-11-20',
#                ...
#                '2018-11-14', '2018-11-13', '2018-11-12', '2018-11-09',
#                '2018-11-08', '2018-11-07', '2018-11-06', '2018-11-05',
#                '2018-11-02', '2018-11-01'],
#               dtype='datetime64[ns]', name='Date', length=1327, freq=None)

# %%
eur_usd_df.head()
# Out:
#              Price    Open    High     Low Change %   Close
# Date
# 2023-12-01  1.0908  1.0892  1.0913  1.0892    0.20%  1.0908
# 2023-11-30  1.0886  1.0971  1.0985  1.0878   -0.75%  1.0886
# 2023-11-29  1.0968  1.0992  1.1018  1.0960   -0.20%  1.0968
# 2023-11-28  1.0990  1.0954  1.1010  1.0934    0.34%  1.0990
# 2023-11-27  1.0953  1.0937  1.0960  1.0925    0.13%  1.0953

# %%
eur_usd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1327 entries, 2023-12-01 to 2018-11-01
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     1327 non-null   float64
#  1   Open      1327 non-null   float64
#  2   High      1327 non-null   float64
#  3   Low       1327 non-null   float64
#  4   Change %  1327 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 62.2+ KB

# %%
mpf.plot(eur_usd_df.loc[:pd.to_datetime('2023-05-19')], type='candle',mav=(3,6,9), figsize=(15,15))
